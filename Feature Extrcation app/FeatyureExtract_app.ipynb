# %%
import pandas as pd
import tkinter as tk
from tkinter import filedialog
from openai import ChatCompletion
import gensim
# Additional imports as required
import os
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


class FeatureExtractorApp:
    def __init__(self):
        self.root = tk.Tk()
        self.root.title("Feature Extractor")
        # GUI elements (buttons, text fields, etc.)
        # Initialize other necessary variables

    def upload_excel(self):
        # Function to upload Excel file and process it
        pass

    def ask_openai_api_key(self):
        # Function to prompt user for OpenAI API key
        pass

    def choose_model(self):
        # Function to let user choose the AI model
        pass

    def check_chroma_db(self):
        # Function to check for Chroma DB vector database
        pass

    def create_or_load_vector_db(self):
        # Function to create or load the Chroma DB vector database
        pass

    def extract_features(self):
        # Function to use ChatGPT for feature extraction
        pass

    def save_new_excel(self):
        # Function to save the updated Excel file
        pass

    def run(self):
        # Run the main application loop
        self.root.mainloop()

if __name__ == "__main__":
    app = FeatureExtractorApp()
    app.run()

# %%
def upload_excel(self):
    file_path = filedialog.askopenfilename(filetypes=[("Excel files", "*.xlsx;*.xls")])
    if not file_path:  # No file was selected
        return None

    # Read the Excel file
    self.dataframe = pd.read_excel(file_path)
    print("Excel file uploaded and read successfully.")


def ask_openai_api_key(self):
    def save_api_key():
        self.api_key = api_key_entry.get()
        api_key_window.destroy()
        print("API Key saved.")

    api_key_window = tk.Toplevel(self.root)
    api_key_window.title("Enter OpenAI API Key")
    
    tk.Label(api_key_window, text="API Key:").pack()
    api_key_entry = tk.Entry(api_key_window)
    api_key_entry.pack()
    tk.Button(api_key_window, text="Save", command=save_api_key).pack()

def choose_model(self):
    def save_model_choice():
        self.model_choice = model_var.get()
        model_window.destroy()
        print(f"Model chosen: {self.model_choice}")

    model_window = tk.Toplevel(self.root)
    model_window.title("Choose Model")

    model_var = tk.StringVar()
    models = [("ChatGPT-3.5-turbo", "gpt-3.5-turbo"), ("ChatGPT-4", "gpt-4")]
    for text, model in models:
        tk.Radiobutton(model_window, text=text, variable=model_var, value=model).pack()
    
    tk.Button(model_window, text="Save", command=save_model_choice).pack()

def check_chroma_db(self):
    db_path = filedialog.askopenfilename(title="Select Chroma DB Vector Database", filetypes=[("Pickle files", "*.pkl")])
    if db_path and os.path.exists(db_path):
        self.load_vector_db(db_path)
    else:
        self.create_vector_db()
def load_vector_db(self, db_path):
    with open(db_path, 'rb') as db_file:
        self.vector_db = pickle.load(db_file)
    print("Vector database loaded successfully.")

def create_vector_db(self):
    # Assuming 'self.dataframe' contains the text data in a column named 'text'
    texts = self.dataframe['text'].tolist()
    
    # Create TF-IDF vectors
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(texts)

    # Optionally, you can use other techniques to create vectors, e.g., word embeddings

    # Save the vectorizer and matrix for future use
    self.vector_db = {'vectorizer': vectorizer, 'tfidf_matrix': tfidf_matrix}
    
    # Save to file
    with open('chroma_db.pkl', 'wb') as db_file:
        pickle.dump(self.vector_db, db_file)

    print("New vector database created and saved.")


def extract_features(self):
    openai.api_key = self.api_key
    for index, row in self.dataframe.iterrows():
        if needs_feature_extraction(row):  # Define this function based on your criteria
            response = openai.Completion.create(
                model=self.model_choice,
                prompt=create_prompt(row),  # Define how to create a prompt from the row
                max_tokens=50  # Adjust as necessary
            )
            self.dataframe.at[index, 'extracted_feature'] = response.choices[0].text.strip()
    print("Feature extraction completed.")

def save_new_excel(self):
    file_path = filedialog.asksaveasfilename(defaultextension=".xlsx", filetypes=[("Excel files", "*.xlsx")])
    if not file_path:
        return
    self.dataframe.to_excel(file_path, index=False)
    print("New Excel file saved.")
